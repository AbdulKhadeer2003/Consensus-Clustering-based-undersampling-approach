# %%
# import pandas as pd
# df_1=pd.read_csv('abalone19-5-1tra.csv')
# df_2=pd.read_csv('abalone19-5-1tst.csv')
# print(df_1.shape)
# df_1.head()

# %%
# print(df_2.shape)
# df_2.head()

# %%
# dataset=pd.concat([df_1,df_2])
# dataset.to_csv("ablone.csv")

# %%
dataset=pd.read_csv("DataSets/ablone.csv")
dataset=dataset.drop(columns=['Unnamed: 0'])
dataset.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight     Class
# 0         0.150  negative
# 1         0.070  negative
# 2         0.210  negative
# 3         0.155  negative
# 4         0.055  negative

# %%
import matplotlib.pyplot as plt
counts = dataset["Class"].value_counts()
plt.pie(counts, autopct="%0.2f%%")
plt.legend(counts.index)
plt.title("Positive to Negative cases ratio")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categoricals = ["Sex", "Class"]
for i in categoricals:
    dataset[i] = le.fit_transform(dataset[i])
dataset.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Class
# 0          0.1010         0.150      0
# 1          0.0485         0.070      0
# 2          0.1415         0.210      0
# 3          0.1140         0.155      0
# 4          0.0395         0.055      0

# %%
# Replace the name of one column
new_column_name = "result"  # Replace with your desired column name
column_to_replace = "Class"  # Replace with the name of the column you want to replace
dataset.rename(columns={column_to_replace: new_column_name}, inplace=True)

# %%
dataset.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  result
# 0          0.1010         0.150       0
# 1          0.0485         0.070       0
# 2          0.1415         0.210       0
# 3          0.1140         0.155       0
# 4          0.0395         0.055       0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset.drop(columns=['result']), dataset['result'], test_size=0.2)
X_train,y_train
# Out:
# (      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
#  1402    1   0.485     0.365   0.105        0.5205          0.1950
#  3263    2   0.560     0.450   0.145        0.9355          0.4250
#  3872    2   0.545     0.450   0.150        0.8795          0.3870
#  2956    2   0.675     0.510   0.170        1.5270          0.8090
#  3210    1   0.275     0.200   0.070        0.0960          0.0370
#  ...   ...     ...       ...     ...           ...             ...
#  751     1   0.435     0.325   0.120        0.3995          0.1815
#  829     2   0.645     0.500   0.175        1.3385          0.6330
#  591     2   0.505     0.380   0.130        0.6560          0.2270
#  3019    2   0.620     0.480   0.155        1.2555          0.5270
#  3747    0   0.640     0.480   0.145        1.1145          0.5080
#
#        Viscera_weight  Shell_weight
#  1402          0.1230        0.1820
#  3263          0.1645        0.2725
#  3872          0.1500        0.2625
#  2956          0.3180        0.3410
#  3210          0.0225        0.0300
#  ...              ...           ...
#  751           0.0610        0.1125
#  829           0.2990        0.3490
#  591           0.1785        0.2200
#  3019          0.3740        0.3175
#  3747          0.2400        0.3400
#
#  [3339 rows x 8 columns],
#  1402    0
#  3263    0
#  3872    0
#  2956    0
#  3210    0
#         ..
#  751     0
#  829     0
#  591     0
#  3019    0
#  3747    0
#  Name: result, Length: 3339, dtype: int32)

# %%
training_data=X_train.assign(result=y_train)
training_data
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 1402    1   0.485     0.365   0.105        0.5205          0.1950
# 3263    2   0.560     0.450   0.145        0.9355          0.4250
# 3872    2   0.545     0.450   0.150        0.8795          0.3870
# 2956    2   0.675     0.510   0.170        1.5270          0.8090
# 3210    1   0.275     0.200   0.070        0.0960          0.0370
# ...   ...     ...       ...     ...           ...             ...
# 751     1   0.435     0.325   0.120        0.3995          0.1815
# 829     2   0.645     0.500   0.175        1.3385          0.6330
# 591     2   0.505     0.380   0.130        0.6560          0.2270
# 3019    2   0.620     0.480   0.155        1.2555          0.5270
# 3747    0   0.640     0.480   0.145        1.1145          0.5080
#
#       Viscera_weight  Shell_weight  result
# 1402          0.1230        0.1820       0
# 3263          0.1645        0.2725       0
# 3872          0.1500        0.2625       0
# 2956          0.3180        0.3410       0
# 3210          0.0225        0.0300       0
# ...              ...           ...     ...
# 751           0.0610        0.1125       0
# 829           0.2990        0.3490       0
# 591           0.1785        0.2200       0
# 3019          0.3740        0.3175       0
# 3747          0.2400        0.3400       0
#
# [3339 rows x 9 columns]

# %%
testing_data=X_test.assign(result=y_test)
testing_data
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 3006    0   0.560     0.430   0.145        0.8980          0.3895
# 915     2   0.580     0.455   0.150        1.1140          0.4765
# 2252    2   0.590     0.470   0.155        1.1735          0.6245
# 675     1   0.415     0.320   0.110        0.3735          0.1750
# 2114    2   0.595     0.460   0.140        0.8520          0.4215
# ...   ...     ...       ...     ...           ...             ...
# 3681    2   0.580     0.430   0.130        0.7980          0.3650
# 2303    2   0.575     0.450   0.165        0.9655          0.4980
# 1045    1   0.555     0.430   0.140        0.7665          0.3410
# 26      2   0.355     0.290   0.090        0.3275          0.1340
# 3222    1   0.540     0.420   0.140        0.7400          0.3595
#
#       Viscera_weight  Shell_weight  result
# 3006          0.2325        0.2450       0
# 915           0.2155        0.2650       0
# 2252          0.2330        0.2595       0
# 675           0.0755        0.1090       0
# 2114          0.2255        0.2270       0
# ...              ...           ...     ...
# 3681          0.1730        0.2285       0
# 2303          0.1900        0.2300       0
# 1045          0.1650        0.2300       0
# 26            0.0860        0.0900       0
# 3222          0.1590        0.1985       0
#
# [835 rows x 9 columns]

# %%
testing_data.to_csv("DataSets/abalone_test.csv")

# %%
class_minority_df=training_data[training_data['result']==1]
class_minority_df.shape
# Out:
# (25, 9)

# %%
class_minority_df.head()
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 3423    2   0.600     0.500   0.160        1.0150          0.3995
# 2709    2   0.645     0.515   0.185        1.4605          0.5835
# 541     0   0.530     0.410   0.165        0.8115          0.2400
# 1865    2   0.695     0.570   0.230        1.8850          0.8665
# 254     2   0.595     0.455   0.195        1.3305          0.4595
#
#       Viscera_weight  Shell_weight  result
# 3423          0.1735         0.330       1
# 2709          0.3155         0.410       1
# 541           0.1690         0.240       1
# 1865          0.4350         0.500       1
# 254           0.3235         0.345       1

# %%
class_majority_df=training_data[training_data['result']==0]
print(class_majority_df.shape)
class_majority_df.head()
# Out:
# (3314, 9)
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 1402    1   0.485     0.365   0.105        0.5205           0.195
# 3263    2   0.560     0.450   0.145        0.9355           0.425
# 3872    2   0.545     0.450   0.150        0.8795           0.387
# 2956    2   0.675     0.510   0.170        1.5270           0.809
# 3210    1   0.275     0.200   0.070        0.0960           0.037
#
#       Viscera_weight  Shell_weight  result
# 1402          0.1230        0.1820       0
# 3263          0.1645        0.2725       0
# 3872          0.1500        0.2625       0
# 2956          0.3180        0.3410       0
# 3210          0.0225        0.0300       0

# %%
class_majority_df.to_csv('DataSets/abalone_majority.csv')
class_minority_df.to_csv('DataSets/abalone_minority.csv')
